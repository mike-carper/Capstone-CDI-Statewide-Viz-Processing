# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import datetime as dt

# %%
fileName = 'C:/Users/mcarp/OneDrive/Documents/tracts.csv'
tracts = pd.read_csv(fileName, index_col=0)
dftracts=pd.DataFrame(tracts)

# %%
dftracts.head()
# Out:
#    Year       Tract     County  Overall Score  College/CTE  Broadband Avail.  \
# 0  2019  6017030200  El Dorado          0.577        0.235             0.774
# 1  2018  6017030200  El Dorado            NaN        0.258             0.771
# 2  2017  6017030200  El Dorado            NaN        0.269             0.793
# 3  2016  6017030200  El Dorado          0.478        0.276               NaN
# 4  2015  6017030200  El Dorado          0.418        0.281               NaN
#
#    Affordable Rent  Home Ownership  Air Quality  Short Commute  \
# 0             0.49           0.429           16           18.8
# 1             0.54           0.442           20           19.6
# 2             0.62           0.460           19           18.9
# 3             0.61           0.444           19           18.0
# 4             0.54           0.418           18           16.2
#
#    Early Childhood Ed.  Drinking Water  Cost of Living  Prosperous Neighbs.
# ...

# %%
def plot_indicators(tract):
    df = dftracts[dftracts['Tract']==tract]
    for x in df.columns[3:]:
        plt.plot(df.Year,df['{}'.format(x)],'o-')
        plt.title('Tract {}: {}'.format(tract,x))
        plt.xlabel('Year')
        plt.ylabel('{}'.format(x))
        plt.xticks(range(2010,2020))
        plt.show()

# %%
tractList=[6017030200,6017030301,6017030302, 6017030401,6017030402,6017030502,6017030504,6017030505,6017031600,6017032000,6061020104,6061020105,6061020106,6061020107,6061022100,6061022200,6061022300]
for tract in tractList:
    plot_indicators(tract)

# %%
def plot_indicators2(tract):
    df = dftracts[dftracts['Tract']==tract]
    fig, axes = plt.subplots(nrows = 4, ncols = 3, figsize = (18,24), constrained_layout = True, subplot_kw = dict(aspect='equal'))
    
    ax1 = axes[0][0]
    ax2 = axes[0][1]
    ax3 = axes[0][2]
    ax4 = axes[1][0]
    ax5 = axes[1][1]
    ax6 = axes[1][2]
    ax7 = axes[2][0]
    ax8 = axes[2][1]
    ax9 = axes[2][2]
    ax10 = axes[3][0]
    ax11 = axes[3][1]

    df['Overall Score'].plot.line(ax=ax1)
    ax1.set(title='{}'.format(df.columns[3]))
    ax1.set_xticks(range(2010,2020))
    #ax1.set_yticks(range(int(df['Overall Score'].min()), int(df['Overall Score'].max())))
    
    df['College/CTE'].plot.line(ax=ax2)
    ax2.set(title='{}'.format(df.columns[4]))
    ax2.set_xticks(range(2010,2020))
    #ax2.set_yticks(range(int(df['College/CTE'].min()), int(df['College/CTE'].max())))
    
    df['Broadband Avail.'].plot.line(ax=ax3)
    ax3.set(title='{}'.format(df.columns[5]))
    ax3.set_xticks(range(2010,2020))
    #ax3.set_yticks(range(int(df['Broadband Avail.'].min()), int(df['Broadband Avail.'].max())))
    
    df['Affordable Rent'].plot.line(ax=ax4)
    ax4.set(title='{}'.format(df.columns[6]))
    ax4.set_xticks(range(2010,2020))
    #ax4.set_yticks(range(int(df['Overall Score'].min()), int(df['Overall Score'].max())))
    
    df['Home Ownership'].plot.line(ax=ax5)
    ax5.set(title='{}'.format(df.columns[7]))
    ax5.set_xticks(range(2010,2020))
    #ax5.set_yticks(range(int(df['Home Ownership'].min()), int(df['Home Ownership'].max())))
    
    df['Air Quality'].plot.line(ax=ax6)
    ax6.set(title='{}'.format(df.columns[8]))
    ax6.set_xticks(range(2010,2020))
    #ax6.set_yticks(range(int(df['Air Quality'].min()), int(df['Air Quality'].max())))
    
    df['Short Commute'].plot.line(ax=ax7)
    ax7.set(title='{}'.format(df.columns[9]))
    ax7.set_xticks(range(2010,2020))
    #ax7.set_yticks(range(int(df['Short Commute'].min()), int(df['Short Commute'].max())))
    
    df['Early Childhood Ed.'].plot.line(ax=ax8)
    ax8.set(title='{}'.format(df.columns[10]))
    ax8.set_xticks(range(2010,2020))
    #ax8.set_yticks(range(int(df['Early Childhood Ed.'].min()), int(df['Early Childhood Ed.'].max())))
    
    df['Drinking Water'].plot.line(ax=ax9)
    ax9.set(title='{}'.format(df.columns[11]))
    ax9.set_xticks(range(2010,2020))
    #ax9.set_yticks(range(int(df['Overall Score'].min()), int(df['Overall Score'].max())))
    
    df['Cost of Living'].plot.line(ax=ax10)
    ax10.set(title='{}'.format(df.columns[12]))
    ax10.set_xticks(range(2010,2020))
    #ax10.set_yticks(range(int(df['Cost of Living'].min()), int(df['Cost of Living'].max())))
    
    df['Prosperous Neighbs.'].plot.line(ax=ax11)
    ax11.set(title='{}'.format(df.columns[13]))
    ax11.set_xticks(range(2010,2020))
    #ax11.set_yticks(range(int(df['Prosperous Neighbs.'].min()), int(df['Prosperous Neighbs.'].max())))
    
    fig.suptitle('Tract {}'.format(tract), fontsize=16)
    plt.show()
